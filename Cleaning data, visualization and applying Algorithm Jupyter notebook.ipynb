# %%
import pandas as pd
from pandas import DataFrame as df

# %%
clickstream = pd.read_csv("C://Users//Dikhsha//FinalSpreadsheet_dikshapaliwal.xlsx - Sheet3.csv")

data = pd.DataFrame(clickstream)

data[:].fillna("N0", inplace = True) 

data = data.drop(columns = "1")
data
# Out:
#       A1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0     A2         A2         A2         A3         A3         A4         A1
# 1     A1         N0         N0         N0         N0         N0         N0
# 2     A4         A4         A4         A4         A4         N0         N0
# 3     A1         A4         A1         A1         A4         A4         A1
# 4     A1         N0         N0         N0         N0         N0         N0
# ..   ...        ...        ...        ...        ...        ...        ...
# 113  A13         A4         A4         A1         N0         N0         N0
# 114   A1         N0         N0         N0         N0         N0         N0
# 115   A1         A4         A1         A4         A1         N0         N0
# 116   A4         A4         A1         N0         N0         N0         N0
# 117   A4         A4         A4         A6         A2         A6         A4
#
# ...

# %%
#data = data.rename_axis('ID').values
#data = data.values.tolist()
#data

Row_list =[] 
  
# Iterate over each row 
for i in range((data.shape[0])): 
  
    # Using iloc to access the values of  
    # the current row denoted by "i" 
    Row_list.append(list(data.iloc[i, :])) 
  
# Print the list 
#print(Row_list)

# %%
clean_list = []

for row in Row_list:
    new_row = []
    for i in range(len(row)):
        if row[i] != "N0" : 
            new_row.append(row[i])
    clean_list.append(new_row)        
print(clean_list)
# Out:
# [['A2', 'A2', 'A2', 'A3', 'A3', 'A4', 'A1'], ['A1'], ['A4', 'A4', 'A4', 'A4', 'A4'], ['A1', 'A4', 'A1', 'A1', 'A4', 'A4', 'A1'], ['A1'], ['A1'], ['A4', 'A4'], ['A4', 'A4'], ['A1'], ['A1', 'A1'], ['A4'], ['A1'], ['A2', 'A1', 'A2', 'A2', 'A2', 'A5', 'A4', 'A1', 'A1'], ['A1'], ['A4', 'A1'], ['A4', 'A1'], ['A1'], ['A1'], ['A2', 'A2', 'A2', 'A6', 'A6', 'A4'], ['A1'], ['A4'], ['A1', 'A4', 'A4'], ['A2', 'A1'], ['A1', 'A1', 'A1', 'A4', 'A5', 'A4', 'A1', 'A7', 'A7', 'A7', 'A6', 'A6', 'A6', 'A4', 'A4', 'A4', 'A1', 'A1', 'A1'], ['A7', 'A7', 'A7', 'A8', 'A4', 'A9', 'A10', 'A4', 'A11', 'A11', 'A11', 'A4', 'A4', 'A4', 'A1', 'A1', 'A1'], ['A1', 'A4', 'A1', 'A4', 'A1'], ['A4', 'A4', 'A1', 'A1', 'A1'], ['A1', 'A1', 'A1', 'A7', 'A7', 'A12', 'A12', 'A12', 'A12', 'A4', 'A4', 'A4', 'A1', 'A1', 'A1', 'A1'], ['A4', 'A4', 'A4', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A4', 'A4', 'A4', 'A1', 'A1', 'A1'], ['A1'], ['A1'], ['A2', 'A2', 'A6', 'A6', 'A4', 'A2', 'A4', 'A13', 'A4'], ['A4'], ['A1', 'A1', 'A1', 'A2
# ...

# %%
from markovclick.models import MarkovClickstream
m = MarkovClickstream(clean_list)

# %%
import seaborn as sns

# %%
sns.heatmap(m.prob_matrix, xticklabels=m.pages, yticklabels=m.pages)
#heatmap indicates the probability matrix,the y axis represnts the current page and the x axis represents the next page.
#The lighter the color the more the probability of 
#to go from onepage to another.

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/Dikhsha/Anaconda3/Library/bin/graphviz/'

# %%
from markovclick.viz import visualise_markov_chain
graph = visualise_markov_chain(m)
graph

# %% [markdown]
# # TRANSACTION DIAGRAM

# %% [markdown]
# #the nodes representing the individual pages are shown in green, and up to 3 edges from each node are rendered.
# #The first edge is in a thick blue arrow, depicting the most likely transition from this page / state to the next page / state.
# #The second edge depicted by a thinner blue arrow, depicts the second most likely transition from this state.
# #Finally, a third edge is shown that depicts the transition from this page / state back to itself (light grey).
# #This edge is only shown if the the two most likely transitions are not already to itself. For all transitions, the probability is shown next to the edge (arrow).

# %% [markdown]
# The maximum probability was of a user going from shop page to the blue lace semi formal dress and brown strappy flats.
